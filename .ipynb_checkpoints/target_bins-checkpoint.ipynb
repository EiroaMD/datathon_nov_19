# %%
# Basic pandas and numpy
import pandas as pd
import numpy as np
 
# Basic visualization tools
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
 
# Pandas defaults
pd.options.display.max_columns = 500
pd.options.display.max_rows = 500
 
# Make jupyter bigger
from IPython.core.display import display, HTML
display(HTML('<style>.container { width:100% !important; }</style>'))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
cookies = pd.read_csv('data/cookies_clean.csv')

# %%
cookies.head()
# Out:
#    Unnamed: 0  sugar to flour ratio  sugar index  bake temp  chill time  \
# 0           0                  0.25          9.5        300        15.0
# 1           1                  0.23          3.3        520        34.0
# 2           2                  0.18          1.9        360        33.0
# 3           3                  0.18         10.5        490        41.0
# 4           4                  0.24          2.4        770         6.0
#
#    calories  density    pH  grams baking soda  bake time  quality butter type  \
# 0     136.0  0.99367  8.10               0.44       12.1        8      melted
# 1     113.0  0.99429  8.16               0.48        8.4        7      melted
# 2     106.0  0.98746  8.21               0.83       14.0        9      melted
# 3     124.0  0.99630  8.14               0.35       10.5        7      melted
# 4      33.0  0.99740  8.09               0.57        9.4        5       cubed
#
#    weight                 mixins  crunch factor  aesthetic appeal
# 0    15.2                raisins           1.30                 3
# 1    12.4                raisins           1.71                 3
# 2     9.4        nuts, chocolate           1.78                 3
# 3    12.2              chocolate           1.59                 3
# 4    19.8  nuts, oats, chocolate           1.30                 3

# %%
def change(x):
    
    if x <= 7:
        return 0
    else:
        return 1

# %%
cookies.quality = cookies.quality.apply(change)

# %%
cookies.head()
# Out:
#    Unnamed: 0  sugar to flour ratio  sugar index  bake temp  chill time  \
# 0           0                  0.25          9.5        300        15.0
# 1           1                  0.23          3.3        520        34.0
# 2           2                  0.18          1.9        360        33.0
# 3           3                  0.18         10.5        490        41.0
# 4           4                  0.24          2.4        770         6.0
#
#    calories  density    pH  grams baking soda  bake time  quality butter type  \
# 0     136.0  0.99367  8.10               0.44       12.1        1      melted
# 1     113.0  0.99429  8.16               0.48        8.4        0      melted
# 2     106.0  0.98746  8.21               0.83       14.0        1      melted
# 3     124.0  0.99630  8.14               0.35       10.5        0      melted
# 4      33.0  0.99740  8.09               0.57        9.4        0       cubed
#
#    weight                 mixins  crunch factor  aesthetic appeal
# 0    15.2                raisins           1.30                 3
# 1    12.4                raisins           1.71                 3
# 2     9.4        nuts, chocolate           1.78                 3
# 3    12.2              chocolate           1.59                 3
# 4    19.8  nuts, oats, chocolate           1.30                 3

# %%
cookies.quality.value_counts()
# Out:
# 1    2576
# 0    2325
# Name: quality, dtype: int64

# %%
cookies.to_csv('data/cookies_target.csv', index=False)
